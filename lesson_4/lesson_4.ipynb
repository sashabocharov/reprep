# %%
import pandas as pd
import os

# %%
os.listdir(r'C:\Users\aleksandr.bocharov\reprep\reprep')
# Out:
# ['.DS_Store', '.git', 'lesson_1', 'lesson_2', 'lesson_3', 'lesson_4', 'other']

# %%
folder_data = [i for i in os.listdir(r'C:\Users\aleksandr.bocharov\reprep\reprep') if i.startswith('lesson')]
folder_data
# Out:
# ['lesson_1', 'lesson_2', 'lesson_3', 'lesson_4']

# %%
x = ['1', '2', '3', 'start', '4', '5', '6', 'end', '7', '8']
x
# Out:
# ['1', '2', '3', 'start', '4', '5', '6', 'end', '7', '8']

# %%
scanning = False
for i in x:
    if i == 'end':
        scanning = False
        continue

    if scanning:
        print(i)

    if i =='start':
        scanning = True
        continue
# Out:
# 4
# 5
# 6

# %%
df = {'co1': ['val1', 'val2', 'val3', 'val4'], 'col2': ['cal1', 'cal2', 'cal3', 'cal4'], 'col3': ['bal1', 'bal2', 'bal3', 'bal4']}
df = pd.DataFrame(df)
df
# Out:
#     co1  col2  col3
# 0  val1  cal1  bal1
# 1  val2  cal2  bal2
# 2  val3  cal3  bal3
# 3  val4  cal4  bal4

# %%
df.shape
# Out:
# (4, 3)

# %%
df_shape = 'df has {y} rows and {x} columns'.format(y = df.shape[0], x= df.shape[1])
df_shape
# Out:
# 'df has 4 rows and 3 columns'

# %%
nan_df = {'co1': ['val1', 'val2', None, 'val4'], 'col2': ['cal1', None, 'cal3', None], 'col3': [None, 'bal2', 'bal3', 'bal4']}
nan_df = pd.DataFrame(nan_df)
nan_df
# Out:
#     co1  col2  col3
# 0  val1  cal1  None
# 1  val2  None  bal2
# 2  None  cal3  bal3
# 3  val4  None  bal4

# %%
nan_df.isnull().sum()
# Out:
# co1     1
# col2    2
# col3    1
# dtype: int64

# %%
df_types = nan_df.dtypes
df_types
# Out:
# co1     object
# col2    object
# col3    object
# dtype: object

# %%
nan_df = nan_df.drop(columns=['co1', 'col2'])
nan_df.dtypes
# Out:
# col3    object
# dtype: object

# %%
numbers = [1, -2, 3, 0, -3, 2]

# %%
positive_numbers = []

# %%
for i in numbers:
    if i == 0:
        break
    if i > 0:
       positive_numbers.append(i)
positive_numbers
# Out:
# [1, 3]

# %%
taxi = pd.read_csv('3_taxi_peru.csv', sep=';')
taxi
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
taxi.dtypes
# Out:
# journey_id           object
# user_id              object
# driver_id            object
# taxi_id              object
# icon                 object
# start_type           object
# start_at             object
# start_lat            object
# start_lon            object
# end_at               object
# end_lat              object
# end_lon              object
# end_state            object
# driver_start_lat     object
# driver_start_lon     object
# arrived_at           object
# source               object
# driver_score        float64
# rider_score         float64
# dtype: object

# %%
for col in ['start_at', 'end_at', 'arrived_at']:
    taxi[col] = pd.to_datetime(taxi[col])
taxi.dtypes
# Out:
# journey_id                  object
# user_id                     object
# driver_id                   object
# taxi_id                     object
# icon                        object
# start_type                  object
# start_at            datetime64[ns]
# start_lat                   object
# start_lon                   object
# end_at              datetime64[ns]
# end_lat                     object
# end_lon                     object
# end_state                   object
# driver_start_lat            object
# driver_start_lon            object
# arrived_at          datetime64[ns]
# source                      object
# driver_score               float64
# rider_score                float64
# dtype: object

# %%
taxi = taxi.loc[taxi['start_type'].isin(['asap', 'reserved'])]

# %%
taxi['wait_time'] = (taxi['arrived_at'] - taxi['start_at']).astype('timedelta64[m]')
taxi
# Out:
# C:\Users\aleksandr.bocharov\AppData\Local\Temp\ipykernel_22892\4212862934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi['wait_time'] = (taxi['arrived_at'] - taxi['start_at']).astype('timedelta64[m]')
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# ...

# %%
late = taxi.loc[taxi.start_type == 'reserved'].loc[taxi.wait_time > 0.0]\
    .driver_id\
    .value_counts()\
    .idxmax()
late
# Out:
# '406921adcca37705ef527b4246c0cfea'

# %%
taxi['month'] = taxi.start_at.dt.month
taxi['weekday'] = taxi.start_at.dt.strftime('%A')
taxi
# Out:
# C:\Users\aleksandr.bocharov\AppData\Local\Temp\ipykernel_22892\518799765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi['month'] = taxi.start_at.dt.month
# C:\Users\aleksandr.bocharov\AppData\Local\Temp\ipykernel_22892\518799765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi['weekday'] = taxi.start_at.dt.strftime('%A')
#                              journey_id                           user_id  \
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x = 'month', data=taxi);

# %%
sns.countplot(x = 'weekday', data=taxi);

# %%
mau = taxi\
    .groupby('month', as_index=False)\
    .agg(uniq_users = ('user_id', 'nunique'))
mau
# Out:
#     month  uniq_users
# 0       1         102
# 1       2         110
# 2       3         162
# 3       4         253
# 4       5         275
# 5       6         309
# 6       7         318
# 7       8         377
# 8       9         416
# 9      10         437
# 10     11         504
# 11     12         569

# %%
mau.plot.line(x='month', y='uniq_users');
